# %%
import os
import json
import pandas as pd

#Read one or many files into a pandas dataframe
class DataFrameBuilder(object):
    def __init__(self):
        self.data_frame = None
        self._data_list = []
    def read_to_pandas(self, path):
        with open(path) as data_file:
            if (path.endswith(".csv")):
                data = pd.read_csv(data_file)
            elif path.endswith(".json"):
                data = pd.read_json(data_file)
            else:
                raise ValueError("No parser exists for parsing %s" + path)
            self._data_list.append(data)
        self.data_frame = pd.concat(self._data_list)

#List all the files available in the selected immuta data source
def list_files(data_frame_builder, startpath):
    for root, dirs, files in os.walk(startpath):
        for file in files:
            path = os.path.join(root, file)
            print path
            #optionally build the pandas dataframe from the files
            data_frame_builder.read_to_pandas(path)

# %% [markdown]
# ### This is your immuta root directory where all your data sources will appear
# If you have none, subscribe to some from the Immuta storefront, otherwise, append a data source of interest to the path.  This will read **ALL** your files to the DF, so be careful what you point it to

# %%
startpath = 'immuta/[enter data source name here]/'
dfb = DataFrameBuilder()
list_files(dfb, startpath)

# %% [markdown]
# ### Do something below with your [pandas dfb.data_frame](http://pandas.pydata.org/pandas-docs/stable/10min.html)

# %%
# !pip install git+git://github.com/seatgeek/fuzzywuzzy.git@0.15.0#egg=fuzzywuzzy
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /opt/conda/envs/python2/lib/python2.7/site-packages

# %%
# %%time

# trying to match course title from STEP to catalog

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import numpy as np
import pickle
import os.path


# function to execute fuzzy match
def findFuzzyMatch(amazonUniqueCourses,matchingCatalog, fname): # parameter: STEP report, training catalog, pickle file name to save
    
    amazonUniqueCoursesSplit = np.array_split(amazonUniqueCourses,amazonUniqueCourses.shape[0]/25) #split df into a batch of 25 rows
    
    for amazonUniqueCourse in amazonUniqueCoursesSplit:
        print "start new batch!"
        fuzzyMatch2 = pd.DataFrame(columns=['StepIndex','STEP Course#','STEP Title','CatalogIndex','Catalog Course#', \
                                       'Catalog Title','Fuzzy Score'])
        for aindex, arow in amazonUniqueCourse.iterrows():
            print("aindex: ",aindex)
            for cindex, crow in matchingCatalog.iterrows():
                fuzzyMatch2 = fuzzyMatch2.append(pd.DataFrame([[aindex, arow['LACODE'], arow['LATITLE'], \
                                                              cindex, crow['course#'], crow['course title'], \
                                                              fuzz.ratio(arow['LATITLE'],crow['course title'])]], \
                                                            columns=['StepIndex','STEP Course#','STEP Title','CatalogIndex', \
                                                                     'Catalog Course#','Catalog Title','Fuzzy Score']), ignore_index=True)
        if os.path.isfile(fname):
            fuzzyMatch = pickle.load(open(fname,'rb'))
            fuzzyMatch = fuzzyMatch.append(fuzzyMatch2)
        else:
            fuzzyMatch = fuzzyMatch2
        pickle.dump(fuzzyMatch, open(fname, "wb" ) )
        fuzzyMatch.info()

#load STEP Report
stepReport = pd.read_csv('immuta/STEP Report/STEP Report.csv')
stepReportExtract = stepReport[['asset_id','asset_title']].drop_duplicates() #pull only the unique courses
stepReportExtract = stepReportExtract.rename(columns={"asset_id": "LACODE", "asset_title": "LATITLE"})     

#Load catalog
catalogBusDec = pd.read_csv('immuta/December 05 2016 Catalog Business Courses/December 05 2016 Catalog Business Courses.csv')


# call fuzzy match function para: STEP, Catalog, pickle file name)
## adjust stepReportExtract[0:50] to different sizes e.g. 100, 500, 1000, all rows
findFuzzyMatch(stepReportExtract[0:50],catalogBusDec, "FuzzyMatchBusFinal.p")

# load fuzzy match result from pickle file
FuzzyMatchBusFinal = pickle.load(open('FuzzyMatchBusFinal.p','rb'))
FuzzyMatchBusFinal
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# start new batch!
# ('aindex: ', 0)
# ('aindex: ', 1)
# ('aindex: ', 2)
# ('aindex: ', 3)
# ('aindex: ', 4)
# ('aindex: ', 5)
# ('aindex: ', 6)
# ('aindex: ', 7)
# ('aindex: ', 8)
# ('aindex: ', 9)
# ('aindex: ', 10)
# ('aindex: ', 11)
# ('aindex: ', 12)
# ('aindex: ', 13)
# ('aindex: ', 14)
# ('aindex: ', 15)
# ('aindex: ', 16)
# ('aindex: ', 18)
# ('aindex: ', 19)
# ('aindex: ', 20)
# ('aindex: ', 21)
# ('aindex: ', 23)
# ('aindex: ', 24)
# ('aindex: ', 25)
# ('aindex: ', 26)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179025 entries, 0 to 25574
# Data columns (total 7 columns):
# StepIndex          179025 non-null float64
# STEP Course#       179025 non-null object
# STEP Title         179025 non-null object
# CatalogIndex       179025 non-null float64
# Catalog Course#    179025 non-null object
# Catalog Title      179025 non-null object
# Fuzzy Score        179025 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 10.9+ MB
# start new batch!
# ('aindex: ', 27)
# ('aindex: ', 28)
# ('aindex: ', 29)
# ('aindex: ', 30)
# ('aindex: ', 31)
# ('aindex: ', 32)
# ('aindex: ', 33)
# ('aindex: ', 34)
# ('aindex: ', 35)
# ('aindex: ', 36)
# ('aindex: ', 37)
# ('aindex: ', 38)
# ('aindex: ', 39)
# ('aindex: ', 40)
# ('aindex: ', 41)
# ('aindex: ', 42)
# ('aindex: ', 43)
# ('aindex: ', 44)
# ('aindex: ', 45)
# ('aindex: ', 46)
# ('aindex: ', 47)
# ('aindex: ', 48)
# ('aindex: ', 49)
# ('aindex: ', 51)
# ('aindex: ', 52)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204600 entries, 0 to 25574
# Data columns (total 7 columns):
# StepIndex          204600 non-null float64
# STEP Course#       204600 non-null object
# STEP Title         204600 non-null object
# CatalogIndex       204600 non-null float64
# Catalog Course#    204600 non-null object
# Catalog Title      204600 non-null object
# Fuzzy Score        204600 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 12.5+ MB
# CPU times: user 5min 7s, sys: 426 ms, total: 5min 7s
# Wall time: 5min 8s

# %%
fuzz.partial_ratio("Black-Box Software Testing Techniques", "White-Box Software Testing Techniques")
# Out:
# 86

# %%
fuzz.partial_ratio("TestPrep 1Z0-808 Java SE 8 Programmer I", "TestPrep 1Z0-809 Java SE 8 Programmer II")
# Out:
# 97

# %%
pd.options.display.max_rows = 1000
FuzzyMatchBusFinal.sort(['Fuzzy Score'], ascending=False).head(1000)
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#        StepIndex         STEP Course#  \
# 2679         2.0    pd_05_a02_bs_enus
# 17939       44.0  comm_26_a02_bs_enus
# 16891       43.0  comm_18_a01_bs_enus
# 14963       40.0    pd_09_a03_bs_enus
# 11253       37.0       _pc_bi_ssbi001
# 11189       10.0  cust_07_a02_bs_enus
# 13124       12.0       _pc_ch_lach023
# 14963       40.0    pd_09_a03_bs_enus
# 12097       11.0       _pc_bi_lsbi010
# 3897         3.0            mntpmp5ed
# 16195       41.0  team_02_a01_bs_enus
# 2679         2.0    pd_05_a02_bs_enus
# 18967       45.0  comm_27_a01_bs_enus
# 18967       45.0  comm_27_a01_bs_enus
# 19374       19.0  cust_07_a03_bs_enus
# 4810         4.0       _pc_bi_pabi004
# 13124       12.0       _pc_ch_lach023
# 19374       19.0  cust_07_a03_bs_enus
# 4793         4.0    pd_23_a02_bs_enus
# 4810         4.0       _pc_bi_pabi004
# 16891       43.0  comm_18_a01_bs_enus
# 12097       11.0       _pc_bi_lsbi010
# 1876        28.0  team_02_a04_bs_enus
# 19991       46.0  comm_27_a02_bs_enus
# 11253       37.0       _pc_bi_ssbi001
# 16195       41.0  team_02_a01_bs_enus
# 3897         3.0            mntpmp5ed
# 17939       44.0  comm_26_a02_bs_enus
# 1876        28.0  team_02_a04_bs_enus
# 19991       46.0  comm_27_a02_bs_enus
# 4793         4.0    pd_23_a02_bs_enus
# 11189       10.0  cust_07_a02_bs_enus
# 5817         5.0    pd_24_a01_bs_enus
# 5817         5.0    pd_24_a01_bs_enus
# 17360       16.0  ib_iosa_a07_it_enus
# 17360       16.0  ib_iosa_a07_it_enus
# 15310       14.0  ib_iosa_a03_it_enus
# 12221       37.0       _pc_bi_ssbi001
# 16334       15.0  ib_iosa_a04_it_enus
# 12221       37.0       _pc_bi_ssbi001
# 15310       14.0  ib_iosa_a03_it_enus
# 16334       15.0  ib_iosa_a04_it_enus
# 22316       23.0  pm_proj_a04_tp_enus
# 14286       13.0  ib_iosa_a02_it_enus
# 22316       23.0  pm_proj_a04_tp_enus
# 14286       13.0  ib_iosa_a02_it_enus
# 9967         9.0  proj_04_a05_bs_enus
# 18350       18.0  cust_02_a02_bs_enus
# 9967         9.0  proj_04_a05_bs_enus
# 18350       18.0  cust_02_a02_bs_enus
# 18244       18.0  cust_02_a02_bs_enus
# 15309       14.0  ib_iosa_a03_it_enus
# 14287       13.0  ib_iosa_a02_it_enus
# 18244       18.0  cust_02_a02_bs_enus
# 14287       13.0  ib_iosa_a02_it_enus
# 15309       14.0  ib_iosa_a03_it_enus
# 19393       18.0  ib_itlu_a06_it_enus
# 5871         5.0  proj_04_a01_bs_enus
# 19393       18.0  ib_itlu_a06_it_enus
# 19992       46.0  comm_27_a02_bs_enus
# 17355       16.0  ib_iosa_a07_it_enus
# 19992       46.0  comm_27_a02_bs_enus
# 17355       16.0  ib_iosa_a07_it_enus
# 15316       14.0  ib_iosa_a03_it_enus
# 15316       14.0  ib_iosa_a03_it_enus
# 5871         5.0  proj_04_a01_bs_enus
# 16198       15.0        ADM0103000000
# 16198       15.0        ADM0103000000
# 18365       17.0  ib_itlu_a01_it_enus
# 17362       16.0  ib_iosa_a07_it_enus
# 20418       19.0  ib_itlu_a08_it_enus
# 17193       16.0  ib_iosa_a07_it_enus
# 14293       13.0  ib_iosa_a02_it_enus
# 18365       17.0  ib_itlu_a01_it_enus
# 17362       16.0  ib_iosa_a07_it_enus
# 14293       13.0  ib_iosa_a02_it_enus
# 20418       19.0  ib_itlu_a08_it_enus
# 17193       16.0  ib_iosa_a07_it_enus
# 17356       16.0  ib_iosa_a07_it_enus
# 18969       45.0  comm_27_a01_bs_enus
# 17356       16.0  ib_iosa_a07_it_enus
# 18969       45.0  comm_27_a01_bs_enus
# 14291       13.0  ib_iosa_a02_it_enus
# 14291       13.0  ib_iosa_a02_it_enus
# 10810       36.0  comm_02_a01_bs_enus
# 580          0.0  comm_02_a01_bs_enus
# 10810       36.0  comm_02_a01_bs_enus
# 15314       14.0  ib_iosa_a03_it_enus
# 23445       49.0       COMM8226000000
# 580          0.0  comm_02_a01_bs_enus
# 15314       14.0  ib_iosa_a03_it_enus
# 23445       49.0       COMM8226000000
# 4494         4.0       _pc_bi_pabi004
# 4494         4.0       _pc_bi_pabi004
# 25100       53.0       en_us_69774_ek
# 3853         3.0  proj_07_a01_bs_enus
# 25100       53.0       en_us_69774_ek
# 3853         3.0  proj_07_a01_bs_enus
# 5818         5.0    pd_24_a01_bs_enus
# 5818         5.0    pd_24_a01_bs_enus
# 19993       46.0  comm_27_a02_bs_enus
# 20672       47.0  cl_clbp_a01_it_enus
# 9227        34.0       CUST8103000000
# 3847         3.0            mntpmp5ed
# 3847         3.0            mntpmp5ed
# 9227        34.0       CUST8103000000
# 20672       47.0  cl_clbp_a01_it_enus
# 19993       46.0  comm_27_a02_bs_enus
# 18970       45.0  comm_27_a01_bs_enus
# 14961       40.0    pd_09_a03_bs_enus
# 14961       40.0    pd_09_a03_bs_enus
# 14962       40.0    pd_09_a03_bs_enus
# 18970       45.0  comm_27_a01_bs_enus
# 15916       15.0        ADM0103000000
# 12152       37.0       _pc_bi_ssbi001
# 15916       15.0        ADM0103000000
# 12152       37.0       _pc_bi_ssbi001
# 14962       40.0    pd_09_a03_bs_enus
# 13777       39.0       COMM0233000000
# 21442       20.0  ib_itlu_a09_it_enus
# 9143         8.0       COMM8003000000
# 8858         8.0       COMM8003000000
# 9143         8.0       COMM8003000000
# 21442       20.0  ib_itlu_a09_it_enus
# 13777       39.0       COMM0233000000
# 8858         8.0       COMM8003000000
# 18968       45.0  comm_27_a01_bs_enus
# 3902         3.0            mntpmp5ed
# 13827       13.0           242528_eng
# 18968       45.0  comm_27_a01_bs_enus
# 13827       13.0           242528_eng
# 3902         3.0            mntpmp5ed
# 3846         3.0            mntpmp5ed
# 22311       23.0  pm_proj_a04_tp_enus
# 12203       11.0       CUST8102000000
# 3846         3.0            mntpmp5ed
# 20415       19.0  ib_itlu_a08_it_enus
# 20415       19.0  ib_itlu_a08_it_enus
# 22311       23.0  pm_proj_a04_tp_enus
# 12203       11.0       CUST8102000000
# 14124       13.0  ib_iosa_a02_it_enus
# 4792         4.0    pd_23_a02_bs_enus
# 20413       19.0  ib_itlu_a08_it_enus
# 19990       46.0  comm_27_a02_bs_enus
# 14124       13.0  ib_iosa_a02_it_enus
# 3898         3.0            mntpmp5ed
# 13967       39.0       COMM0233000000
# 15915       15.0        ADM0103000000
# 13967       39.0       COMM0233000000
# 20413       19.0  ib_itlu_a08_it_enus
# 16284       41.0  team_02_a01_bs_enus
# 15915       15.0        ADM0103000000
# 19990       46.0  comm_27_a02_bs_enus
# 13315       39.0       COMM0233000000
# 3898         3.0            mntpmp5ed
# 17941       44.0  comm_26_a02_bs_enus
# 17941       44.0  comm_26_a02_bs_enus
# 16284       41.0  team_02_a01_bs_enus
# 4792         4.0    pd_23_a02_bs_enus
# 13315       39.0       COMM0233000000
# 14289       13.0  ib_iosa_a02_it_enus
# 14289       13.0  ib_iosa_a02_it_enus
# 15319       14.0  ib_iosa_a03_it_enus
# 23352       22.0       TEAM8223000000
# 15319       14.0  ib_iosa_a03_it_enus
# 18458       19.0  cust_07_a03_bs_enus
# 18458       19.0  cust_07_a03_bs_enus
# 23352       22.0       TEAM8223000000
# 20419       20.0  ib_itil_a09_it_enus
# 15312       14.0  ib_iosa_a03_it_enus
# 14296       13.0  ib_iosa_a02_it_enus
# 16977       43.0  comm_18_a01_bs_enus
# 16977       43.0  comm_18_a01_bs_enus
# 20414       20.0  ib_itil_a09_it_enus
# 20414       20.0  ib_itil_a09_it_enus
# 15147       14.0  ib_iosa_a03_it_enus
# 20419       20.0  ib_itil_a09_it_enus
# 14296       13.0  ib_iosa_a02_it_enus
# 15312       14.0  ib_iosa_a03_it_enus
# 3870         3.0            mntpmp5ed
# 15147       14.0  ib_iosa_a03_it_enus
# 3870         3.0            mntpmp5ed
# 11746       11.0       CUST8102000000
# 24049       25.0           218741_eng
# 11746       11.0       CUST8102000000
# 12178       37.0       _pc_bi_ssbi001
# 3435        30.0           259931_eng
# 20416       19.0  ib_itlu_a08_it_enus
# 4001        30.0           259931_eng
# 8089         7.0  comm_11_a02_bs_enus
# 1570        28.0  team_02_a04_bs_enus
# 8089         7.0  comm_11_a02_bs_enus
# 20416       19.0  ib_itlu_a08_it_enus
# 3865         3.0            mntpmp5ed
# 10274       10.0  cust_07_a02_bs_enus
# 24049       25.0           218741_eng
# 3734        30.0           259931_eng
# 20412       20.0  ib_itil_a09_it_enus
# 18288       44.0  comm_26_a02_bs_enus
# 12178       37.0       _pc_bi_ssbi001
# 3435        30.0           259931_eng
# 10274       10.0  cust_07_a02_bs_enus
# 4001        30.0           259931_eng
# 7868         7.0  comm_11_a02_bs_enus
# 7868         7.0  comm_11_a02_bs_enus
# 1570        28.0  team_02_a04_bs_enus
# 3865         3.0            mntpmp5ed
# 10758       10.0  cust_07_a02_bs_enus
# 18288       44.0  comm_26_a02_bs_enus
# 3734        30.0           259931_eng
# 10758       10.0  cust_07_a02_bs_enus
# 20412       20.0  ib_itil_a09_it_enus
# 17810       44.0  comm_26_a02_bs_enus
# 3867         3.0            mntpmp5ed
# 15892       15.0        ADM0103000000
# 3860         3.0            mntpmp5ed
# 17363       16.0  ib_iosa_a07_it_enus
# 6895         6.0  proj_04_a02_bs_enus
# 3871         3.0            mntpmp5ed
# 6903         6.0  proj_04_a02_bs_enus
# 17365       16.0  ib_iosa_a07_it_enus
# 17358       16.0  ib_iosa_a07_it_enus
# 3901         3.0            mntpmp5ed
# 21529       21.0    pd_12_a01_bs_enus
# 17859       44.0  comm_26_a02_bs_enus
# 15927       15.0        ADM0103000000
# 17259       43.0  comm_18_a01_bs_enus
# 13588       39.0       COMM0233000000
# 17130       16.0  ib_iosa_a07_it_enus
# 17859       44.0  comm_26_a02_bs_enus
# 12935       12.0       _pc_ch_lach023
# 17810       44.0  comm_26_a02_bs_enus
# 14294       13.0  ib_iosa_a02_it_enus
# 8775         8.0       COMM8003000000
# 17259       43.0  comm_18_a01_bs_enus
# 22261       23.0  pm_proj_a04_tp_enus
# 17130       16.0  ib_iosa_a07_it_enus
# 8775         8.0       COMM8003000000
# 17365       16.0  ib_iosa_a07_it_enus
# 17363       16.0  ib_iosa_a07_it_enus
# 17358       16.0  ib_iosa_a07_it_enus
# 19395       18.0  ib_itlu_a06_it_enus
# 14294       13.0  ib_iosa_a02_it_enus
# 13588       39.0       COMM0233000000
# 3845         3.0            mntpmp5ed
# 12935       12.0       _pc_ch_lach023
# 12674       12.0       _pc_ch_lach023
# 21529       21.0    pd_12_a01_bs_enus
# 3901         3.0            mntpmp5ed
# 15927       15.0        ADM0103000000
# 3860         3.0            mntpmp5ed
# 3871         3.0            mntpmp5ed
# 15892       15.0        ADM0103000000
# 6903         6.0  proj_04_a02_bs_enus
# 3867         3.0            mntpmp5ed
# 22261       23.0  pm_proj_a04_tp_enus
# 19395       18.0  ib_itlu_a06_it_enus
# 6895         6.0  proj_04_a02_bs_enus
# 3845         3.0            mntpmp5ed
# 12674       12.0       _pc_ch_lach023
# 17901       44.0  comm_26_a02_bs_enus
# 959         27.0         PD0133000000
# 12223       37.0       _pc_bi_ssbi001
# 3843         3.0            mntpmp5ed
# 3843         3.0            mntpmp5ed
# 1551        28.0  team_02_a04_bs_enus
# 3866         3.0            mntpmp5ed
# 11771       37.0       _pc_bi_ssbi001
# 17973       18.0  cust_02_a02_bs_enus
# 21437       20.0  ib_itlu_a09_it_enus
# 21437       20.0  ib_itlu_a09_it_enus
# 24596       52.0       CUST8182000000
# 3864         3.0            mntpmp5ed
# 10778       10.0  cust_07_a02_bs_enus
# 6896         6.0  proj_04_a02_bs_enus
# 3866         3.0            mntpmp5ed
# 10778       10.0  cust_07_a02_bs_enus
# 1973         1.0       CUST8126000000
# 1973         1.0       CUST8126000000
# 17973       18.0  cust_02_a02_bs_enus
# 12223       37.0       _pc_bi_ssbi001
# 11771       37.0       _pc_bi_ssbi001
# 959         27.0         PD0133000000
# 3864         3.0            mntpmp5ed
# 24596       52.0       CUST8182000000
# 6896         6.0  proj_04_a02_bs_enus
# 17901       44.0  comm_26_a02_bs_enus
# 1551        28.0  team_02_a04_bs_enus
# 14152       13.0           242528_eng
# 15317       14.0  ib_iosa_a03_it_enus
# 21435       20.0  ib_itlu_a09_it_enus
# 15311       14.0  ib_iosa_a03_it_enus
# 15311       14.0  ib_iosa_a03_it_enus
# 6945         6.0  proj_04_a02_bs_enus
# 7816        34.0           259943_eng
# 1024        26.0                35331
# 14152       13.0           242528_eng
# 18593       19.0  cust_07_a03_bs_enus
# 15084       14.0  ib_iosa_a03_it_enus
# 7816        34.0           259943_eng
# 15317       14.0  ib_iosa_a03_it_enus
# 24562       52.0       CUST8182000000
# 16269       15.0        ADM0103000000
# 22224       21.0    pd_12_a01_bs_enus
# 1024        26.0                35331
# 21435       20.0  ib_itlu_a09_it_enus
# 22224       21.0    pd_12_a01_bs_enus
# 1635        28.0  team_02_a04_bs_enus
# 3859         3.0            mntpmp5ed
# 1605        28.0  team_02_a04_bs_enus
# 6945         6.0  proj_04_a02_bs_enus
# 23356       49.0       COMM8226000000
# 23356       49.0       COMM8226000000
# 1605        28.0  team_02_a04_bs_enus
# 16269       15.0        ADM0103000000
# 1635        28.0  team_02_a04_bs_enus
# 15084       14.0  ib_iosa_a03_it_enus
# 24562       52.0       CUST8182000000
# 18593       19.0  cust_07_a03_bs_enus
# 3859         3.0            mntpmp5ed
# 16333       15.0  ib_iosa_a04_it_enus
# 16332       15.0  ib_iosa_a04_it_enus
# 7709         7.0  comm_11_a02_bs_enus
# 14061       13.0  ib_iosa_a02_it_enus
# 13804       39.0       COMM0233000000
# 3782        30.0           259931_eng
# 8094         7.0  comm_11_a02_bs_enus
# 15915       41.0  team_02_a01_bs_enus
# 6202        33.0           259942_eng
# 3842         3.0            mntpmp5ed
# 13795       39.0       COMM0233000000
# 13846       39.0       COMM0233000000
# 12723       12.0       _pc_ch_lach023
# 17919       18.0  cust_02_a02_bs_enus
# 13811       39.0       COMM0233000000
# 7709         7.0  comm_11_a02_bs_enus
# 8228         8.0       COMM8003000000
# 17258       43.0  comm_18_a01_bs_enus
# 8228         8.0       COMM8003000000
# 17258       43.0  comm_18_a01_bs_enus
# 8877         8.0       COMM8003000000
# 8877         8.0       COMM8003000000
# 20417       19.0  ib_itlu_a08_it_enus
# 13846       39.0       COMM0233000000
# 17903       44.0  comm_26_a02_bs_enus
# 17919       18.0  cust_02_a02_bs_enus
# 16333       15.0  ib_iosa_a04_it_enus
# 13811       39.0       COMM0233000000
# 16332       15.0  ib_iosa_a04_it_enus
# 13804       39.0       COMM0233000000
# 15915       41.0  team_02_a01_bs_enus
# 6202        33.0           259942_eng
# 13191       12.0       _pc_ch_lach023
# 17903       44.0  comm_26_a02_bs_enus
# 3842         3.0            mntpmp5ed
# 19392       18.0  ib_itlu_a06_it_enus
# 13795       39.0       COMM0233000000
# 12723       12.0       _pc_ch_lach023
# 8094         7.0  comm_11_a02_bs_enus
# 14061       13.0  ib_iosa_a02_it_enus
# 20417       19.0  ib_itlu_a08_it_enus
# 13191       12.0       _pc_ch_lach023
# 19392       18.0  ib_itlu_a06_it_enus
# 3782        30.0           259931_eng
# 9134        33.0       CUST0163000000
# 19390       18.0  ib_itlu_a06_it_enus
# 8663        33.0       CUST0163000000
# 11805       37.0       _pc_bi_ssbi001
# 8120         7.0  comm_11_a02_bs_enus
# 17354       16.0  ib_iosa_a07_it_enus
# 11864       37.0       _pc_bi_ssbi001
# 14285       13.0  ib_iosa_a02_it_enus
# 15916       41.0  team_02_a01_bs_enus
# 10276       37.0  lu_lalp_a04_it_enus
# 10276       37.0  lu_lalp_a04_it_enus
# 8663        33.0       CUST0163000000
# 24008       51.0       CUST0163000000
# 24008       51.0       CUST0163000000
# 11864       37.0       _pc_bi_ssbi001
# 24479       51.0       CUST0163000000
# 24479       51.0       CUST0163000000
# 17260       43.0  comm_18_a01_bs_enus
# 11805       37.0       _pc_bi_ssbi001
# 14288       13.0  ib_iosa_a02_it_enus
# 17938       18.0  cust_02_a02_bs_enus
# 25512       52.0       CUST8182000000
# 17989       18.0  cust_02_a02_bs_enus
# 9134        33.0       CUST0163000000
# 17260       43.0  comm_18_a01_bs_enus
# 25512       52.0       CUST8182000000
# 17989       18.0  cust_02_a02_bs_enus
# 17938       18.0  cust_02_a02_bs_enus
# 14288       13.0  ib_iosa_a02_it_enus
# 19390       18.0  ib_itlu_a06_it_enus
# 18314       18.0  cust_02_a02_bs_enus
# 8120         7.0  comm_11_a02_bs_enus
# 24758       24.0  pg_cpls_a01_it_enus
# 1960        28.0  team_02_a04_bs_enus
# 24758       24.0  pg_cpls_a01_it_enus
# 12146       37.0       _pc_bi_ssbi001
# 15916       41.0  team_02_a01_bs_enus
# 14285       13.0  ib_iosa_a02_it_enus
# 13620       39.0       COMM0233000000
# 13620       39.0       COMM0233000000
# 1960        28.0  team_02_a04_bs_enus
# 18314       18.0  cust_02_a02_bs_enus
# 12146       37.0       _pc_bi_ssbi001
# 17354       16.0  ib_iosa_a07_it_enus
# 9988         9.0  proj_04_a05_bs_enus
# 18319       44.0  comm_26_a02_bs_enus
# 18350       44.0  comm_26_a02_bs_enus
# 4762         4.0       _pc_bi_pabi004
# 15681       15.0        ADM0103000000
# 17940       44.0  comm_26_a02_bs_enus
# 18528       19.0  cust_07_a03_bs_enus
# 7436        32.0       CONS0121000000
# 9988         9.0  proj_04_a05_bs_enus
# 10649       10.0  cust_07_a02_bs_enus
# 3855         3.0            mntpmp5ed
# 10649       10.0  cust_07_a02_bs_enus
# 18098       44.0  comm_26_a02_bs_enus
# 25102       53.0       en_us_69774_ek
# 22260       23.0  pm_proj_a04_tp_enus
# 3855         3.0            mntpmp5ed
# 24886       52.0       CUST8182000000
# 15878       15.0        ADM0103000000
# 13965       39.0       COMM0233000000
# 13966       39.0       COMM0233000000
# 22260       23.0  pm_proj_a04_tp_enus
# 18319       44.0  comm_26_a02_bs_enus
# 13846       13.0           242528_eng
# 24886       52.0       CUST8182000000
# 18098       44.0  comm_26_a02_bs_enus
# 17940       44.0  comm_26_a02_bs_enus
# 15681       15.0        ADM0103000000
# 13943       13.0           242528_eng
# 18350       44.0  comm_26_a02_bs_enus
# 15943       15.0        ADM0103000000
# 4762         4.0       _pc_bi_pabi004
# 11537       11.0       CUST8102000000
# 11537       11.0       CUST8102000000
# 18528       19.0  cust_07_a03_bs_enus
# 7436        32.0       CONS0121000000
# 13943       13.0           242528_eng
# 1621        28.0  team_02_a04_bs_enus
# 13846       13.0           242528_eng
# 15878       15.0        ADM0103000000
# 25102       53.0       en_us_69774_ek
# 15943       15.0        ADM0103000000
# 21963       21.0    pd_12_a01_bs_enus
# 13965       39.0       COMM0233000000
# 18804       19.0  cust_07_a03_bs_enus
# 21963       21.0    pd_12_a01_bs_enus
# 13966       39.0       COMM0233000000
# 18804       19.0  cust_07_a03_bs_enus
# 1621        28.0  team_02_a04_bs_enus
# 1995         1.0       CUST8126000000
# 11913       11.0       _pc_bi_lsbi010
# 18654       19.0  cust_07_a03_bs_enus
# 3861         3.0            mntpmp5ed
# 24666       52.0       CUST8182000000
# 11913       11.0       _pc_bi_lsbi010
# 24666       52.0       CUST8182000000
# 24661       52.0       CUST8182000000
# 9090        33.0       CUST0163000000
# 11771       11.0       _pc_bi_lsbi010
# 24748       52.0       CUST8182000000
# 11774       11.0       _pc_bi_lsbi010
# 12650       12.0       _pc_ch_lach023
# 23443       49.0       COMM8226000000
# 7654        32.0       CONS0121000000
# 1928        26.0                35331
# 6667        31.0       COMM0013000000
# 1995         1.0       CUST8126000000
# 24661       52.0       CUST8182000000
# 3490        30.0           259931_eng
# 24435       51.0       CUST0163000000
# 18654       19.0  cust_07_a03_bs_enus
# 15308       14.0  ib_iosa_a03_it_enus
# 44          27.0         PD0133000000
# 3490        30.0           259931_eng
# 16338       15.0  ib_iosa_a04_it_enus
# 13970       39.0       COMM0233000000
# 11771       11.0       _pc_bi_lsbi010
# 25435       52.0       CUST8182000000
# 44          27.0         PD0133000000
# 7921         7.0  proj_04_a03_bs_enus
# 24435       51.0       CUST0163000000
# 9090        33.0       CUST0163000000
# 23443       49.0       COMM8226000000
# 11538       11.0       CUST8102000000
# 20251       46.0  comm_27_a02_bs_enus
# 6667        31.0       COMM0013000000
# 20251       46.0  comm_27_a02_bs_enus
# 7654        32.0       CONS0121000000
# 11538       11.0       CUST8102000000
# 9966         9.0  proj_04_a05_bs_enus
# 11774       11.0       _pc_bi_lsbi010
# 25435       52.0       CUST8182000000
# 1928        26.0                35331
# 13970       39.0       COMM0233000000
# 24748       52.0       CUST8182000000
# 9966         9.0  proj_04_a05_bs_enus
# 11127       10.0  cust_07_a02_bs_enus
# 15308       14.0  ib_iosa_a03_it_enus
# 12650       12.0       _pc_ch_lach023
# 7921         7.0  proj_04_a03_bs_enus
# 11127       10.0  cust_07_a02_bs_enus
# 3861         3.0            mntpmp5ed
# 16338       15.0  ib_iosa_a04_it_enus
# 16342       15.0  ib_iosa_a04_it_enus
# 528          0.0  comm_02_a01_bs_enus
# 16198       41.0  team_02_a01_bs_enus
# 16198       41.0  team_02_a01_bs_enus
# 17435       18.0  cust_02_a02_bs_enus
# 15927       41.0  team_02_a01_bs_enus
# 25546       52.0       CUST8182000000
# 3856         3.0            mntpmp5ed
# 8822         8.0       COMM8003000000
# 22315       23.0  pm_proj_a04_tp_enus
# 24486       51.0       CUST0163000000
# 13236       12.0       CUST8181000000
# 3841         3.0            mntpmp5ed
# 1873        28.0  team_02_a04_bs_enus
# 3856         3.0            mntpmp5ed
# 3841         3.0            mntpmp5ed
# 14283       13.0  ib_iosa_a02_it_enus
# 1873        28.0  team_02_a04_bs_enus
# 10731       37.0  lu_lalp_a04_it_enus
# 8991         8.0  proj_04_a04_bs_enus
# 25032       24.0  pg_cpls_a01_it_enus
# 25546       52.0       CUST8182000000
# 14283       13.0  ib_iosa_a02_it_enus
# 13236       12.0       CUST8181000000
# 12954       12.0       _pc_ch_lach023
# 23077       49.0       COMM8226000000
# 22315       23.0  pm_proj_a04_tp_enus
# 24486       51.0       CUST0163000000
# 7678         7.0  comm_11_a02_bs_enus
# 13084       12.0       _pc_ch_lach023
# 8822         8.0       COMM8003000000
# 10758       36.0  comm_02_a01_bs_enus
# 12954       12.0       _pc_ch_lach023
# 9141        33.0       CUST0163000000
# 16342       15.0  ib_iosa_a04_it_enus
# 8017         7.0  comm_11_a02_bs_enus
# 8991         8.0  proj_04_a04_bs_enus
# 25032       24.0  pg_cpls_a01_it_enus
# 8017         7.0  comm_11_a02_bs_enus
# 3169        30.0           259931_eng
# 3169        30.0           259931_eng
# 13084       12.0       _pc_ch_lach023
# 10731       37.0  lu_lalp_a04_it_enus
# 25101       53.0       en_us_69774_ek
# 10758       36.0  comm_02_a01_bs_enus
# 9141        33.0       CUST0163000000
# 15927       41.0  team_02_a01_bs_enus
# 7678         7.0  comm_11_a02_bs_enus
# 17435       18.0  cust_02_a02_bs_enus
# 3478        30.0           259931_eng
# 528          0.0  comm_02_a01_bs_enus
# 3478        30.0           259931_eng
# 6493        33.0           259942_eng
# 23077       49.0       COMM8226000000
# 6493        33.0           259942_eng
# 25101       53.0       en_us_69774_ek
# 14152       39.0       COMM0233000000
# 14152       39.0       COMM0233000000
# 15306       14.0  ib_iosa_a03_it_enus
# 11911       11.0       _pc_bi_lsbi010
# 2975        29.0           259928_eng
# 11377       11.0       CUST8102000000
# 15873       15.0        ADM0103000000
# 16193       41.0  team_02_a01_bs_enus
# 2200        29.0           259928_eng
# 1982        28.0  team_02_a04_bs_enus
# 13792       39.0       COMM0233000000
# 15806       15.0        ADM0103000000
# 17879       18.0  cust_02_a02_bs_enus
# 15833       15.0        ADM0103000000
# 3849         3.0            mntpmp5ed
# 2659        29.0           259928_eng
# 7359        34.0           259943_eng
# 8943         8.0  proj_04_a04_bs_enus
# 13126       12.0       _pc_ch_lach023
# 3853         3.0            mntpmp5ed
# 8875         8.0       COMM8003000000
# 18230       18.0  cust_02_a02_bs_enus
# 1667        28.0  team_02_a04_bs_enus
# 11190       37.0  lu_lalp_a04_it_enus
# 15714       15.0  ib_iosa_a04_it_enus
# 23076       49.0       COMM8226000000
# 20414       19.0  ib_itlu_a08_it_enus
# 13126       12.0       _pc_ch_lach023
# 8943         8.0  proj_04_a04_bs_enus
# 7359        34.0           259943_eng
# 24487       51.0       CUST0163000000
# 2659        29.0           259928_eng
# 16184       15.0        ADM0103000000
# 5872         5.0  proj_04_a01_bs_enus
# 15306       14.0  ib_iosa_a03_it_enus
# 11190       37.0  lu_lalp_a04_it_enus
# 15806       15.0        ADM0103000000
# 16758       16.0  ib_iosa_a07_it_enus
# 11911       11.0       _pc_bi_lsbi010
# 17352       16.0  ib_iosa_a07_it_enus
# 23076       49.0       COMM8226000000
# 15833       15.0        ADM0103000000
# 8081        32.0       CONS0121000000
# 5830         5.0    pd_24_a01_bs_enus
# 11100       10.0  cust_07_a02_bs_enus
# 7444        32.0       CONS0121000000
# 16193       41.0  team_02_a01_bs_enus
# 2200        29.0           259928_eng
# 1484        28.0  team_02_a04_bs_enus
# 1982        28.0  team_02_a04_bs_enus
# 11377       11.0       CUST8102000000
# 2975        29.0           259928_eng
# 16552       43.0  comm_18_a01_bs_enus
# 24402       51.0       CUST0163000000
# 11100       10.0  cust_07_a02_bs_enus
# 11083       10.0  cust_07_a02_bs_enus
# 13792       39.0       COMM0233000000
# 11083       10.0  cust_07_a02_bs_enus
# 16552       43.0  comm_18_a01_bs_enus
# 17879       18.0  cust_02_a02_bs_enus
# 3853         3.0            mntpmp5ed
# 24487       51.0       CUST0163000000
# 7444        32.0       CONS0121000000
# 16758       16.0  ib_iosa_a07_it_enus
# 3844         3.0            mntpmp5ed
# 18230       18.0  cust_02_a02_bs_enus
# 16337       15.0  ib_iosa_a04_it_enus
# 20414       19.0  ib_itlu_a08_it_enus
# 9142        33.0       CUST0163000000
# 16344       15.0  ib_iosa_a04_it_enus
# 18065       44.0  comm_26_a02_bs_enus
# 18065       44.0  comm_26_a02_bs_enus
# 5872         5.0  proj_04_a01_bs_enus
# 16339       15.0  ib_iosa_a04_it_enus
# 5830         5.0    pd_24_a01_bs_enus
# 24402       51.0       CUST0163000000
# 17352       16.0  ib_iosa_a07_it_enus
# 9057        33.0       CUST0163000000
# 1484        28.0  team_02_a04_bs_enus
# 8875         8.0       COMM8003000000
# 1667        28.0  team_02_a04_bs_enus
# 3849         3.0            mntpmp5ed
# 16184       15.0        ADM0103000000
# 15714       15.0  ib_iosa_a04_it_enus
# 9057        33.0       CUST0163000000
# 8081        32.0       CONS0121000000
# 16337       15.0  ib_iosa_a04_it_enus
# 16339       15.0  ib_iosa_a04_it_enus
# 16344       15.0  ib_iosa_a04_it_enus
# 3844         3.0            mntpmp5ed
# 25544       52.0       CUST8182000000
# 15873       15.0        ADM0103000000
# 9142        33.0       CUST0163000000
# 25544       52.0       CUST8182000000
# 1948         1.0       CUST8126000000
# 7918         7.0  proj_04_a03_bs_enus
# 16253       41.0  team_02_a01_bs_enus
# 23462       51.0  dt_ismu_a01_it_enus
# 5876         5.0  proj_04_a01_bs_enus
# 18424       19.0  cust_07_a03_bs_enus
# 11544       11.0       _pc_bi_lsbi010
# 6163        33.0           259942_eng
# 18424       19.0  cust_07_a03_bs_enus
# 897         27.0         PD0133000000
# 20412       19.0  ib_itlu_a08_it_enus
# 13827       39.0       COMM0233000000
# 7918         7.0  proj_04_a03_bs_enus
# 1511        28.0  team_02_a04_bs_enus
# 11544       11.0       _pc_bi_lsbi010
# 8067        34.0           259943_eng
# 3489        30.0           259931_eng
# 1991         1.0       CUST8126000000
# 24499       51.0       CUST0163000000
# 12910       12.0       _pc_ch_lach023
# 9154        33.0       CUST0163000000
# 18003       18.0  cust_02_a02_bs_enus
# 1926         1.0       CUST8126000000
# 20412       19.0  ib_itlu_a08_it_enus
# 6163        33.0           259942_eng
# 9004         8.0  proj_04_a04_bs_enus
# 12098       11.0       _pc_bi_lsbi010
# 17469       44.0  proj_06_a03_bs_enus
# 13827       39.0       COMM0233000000
# 13006       12.0       _pc_ch_lach023
# 15771       15.0        ADM0103000000
# 582          0.0  comm_02_a01_bs_enus
# 15771       15.0        ADM0103000000
# 24499       51.0       CUST0163000000
# 10740       10.0  cust_07_a02_bs_enus
# 928         27.0         PD0133000000
# 3915        30.0           259931_eng
# 3489        30.0           259931_eng
# 7580         7.0  comm_11_a02_bs_enus
# 10698       10.0  cust_07_a02_bs_enus
# 12098       11.0       _pc_bi_lsbi010
# 20419       19.0  ib_itlu_a08_it_enus
# 25377       52.0       CUST8182000000
# 25539       52.0       CUST8182000000
# 7205         7.0  comm_11_a02_bs_enus
# 16253       41.0  team_02_a01_bs_enus
# 13006       12.0       _pc_ch_lach023
# 897         27.0         PD0133000000
# 24802       52.0       CUST8182000000
# 928         27.0         PD0133000000
# 12910       12.0       _pc_ch_lach023
# 25539       52.0       CUST8182000000
# 10740       10.0  cust_07_a02_bs_enus
# 7327        32.0       CONS0121000000
# 18035       18.0  cust_02_a02_bs_enus
# 1948         1.0       CUST8126000000
# 1991         1.0       CUST8126000000
# 582          0.0  comm_02_a01_bs_enus
# 1511        28.0  team_02_a04_bs_enus
# 11056       37.0  lu_lalp_a04_it_enus
# 9004         8.0  proj_04_a04_bs_enus
# 13585       39.0       COMM0233000000
# 7327        32.0       CONS0121000000
# 10812       36.0  comm_02_a01_bs_enus
# 17059       16.0  ib_iosa_a07_it_enus
# 9154        33.0       CUST0163000000
# 581         27.0         PD0133000000
# 2045        28.0  team_02_a04_bs_enus
# 19327       19.0  cust_07_a03_bs_enus
# 11056       37.0  lu_lalp_a04_it_enus
# 3868         3.0            mntpmp5ed
# 7580         7.0  comm_11_a02_bs_enus
# 5876         5.0  proj_04_a01_bs_enus
# 1926         1.0       CUST8126000000
# 13585       39.0       COMM0233000000
# 12802       12.0       _pc_ch_lach023
# 2251        29.0           259928_eng
# 24942       52.0       CUST8182000000
# 24802       52.0       CUST8182000000
# 3868         3.0            mntpmp5ed
# 10812       36.0  comm_02_a01_bs_enus
# 17469       44.0  proj_06_a03_bs_enus
# 17290       43.0  comm_18_a01_bs_enus
# 10698       10.0  cust_07_a02_bs_enus
# 2251        29.0           259928_eng
# 20419       19.0  ib_itlu_a08_it_enus
# 24942       52.0       CUST8182000000
# 8067        34.0           259943_eng
# 25020       53.0       en_us_69774_ek
# 2045        28.0  team_02_a04_bs_enus
# 7205         7.0  comm_11_a02_bs_enus
# 17971       18.0  cust_02_a02_bs_enus
# 18035       18.0  cust_02_a02_bs_enus
# 18003       18.0  cust_02_a02_bs_enus
# 3915        30.0           259931_eng
# 581         27.0         PD0133000000
# 25020       53.0       en_us_69774_ek
# 17059       16.0  ib_iosa_a07_it_enus
# 19327       19.0  cust_07_a03_bs_enus
# 25377       52.0       CUST8182000000
# 17290       43.0  comm_18_a01_bs_enus
# 23462       51.0  dt_ismu_a01_it_enus
# 17971       18.0  cust_02_a02_bs_enus
# 12802       12.0       _pc_ch_lach023
# 19952       20.0  ib_itil_a09_it_enus
# 7977         7.0  proj_04_a03_bs_enus
# 15942       41.0  team_02_a01_bs_enus
# 8058         7.0  comm_11_a02_bs_enus
# 19297       19.0  cust_07_a03_bs_enus
# 11083       36.0  comm_02_a01_bs_enus
# 10339       37.0  lu_lalp_a04_it_enus
# 7920         7.0  proj_04_a03_bs_enus
# 22957       49.0       COMM8226000000
# 9109        33.0       CUST0163000000
# 7919         7.0  proj_04_a03_bs_enus
# 9076         8.0       COMM8003000000
# 25378       52.0       CUST8182000000
# 15715       15.0  ib_iosa_a04_it_enus
# 10820       36.0  comm_02_a01_bs_enus
# 9207        34.0       CUST8103000000
# 11076       10.0  cust_07_a02_bs_enus
# 11147       37.0  lu_lalp_a04_it_enus
# 22957       49.0       COMM8226000000
# 7977         7.0  proj_04_a03_bs_enus
# 7741         7.0  comm_11_a02_bs_enus
# 7978         7.0  proj_04_a03_bs_enus
# 7741         7.0  comm_11_a02_bs_enus
# 3886        30.0           259931_eng
# 12682       12.0       CUST8181000000
# 7978        34.0           259943_eng
# 24454       51.0       CUST0163000000
# 436         27.0         PD0133000000
# 853          0.0  comm_02_a01_bs_enus
# 10339       37.0  lu_lalp_a04_it_enus
# 19297       19.0  cust_07_a03_bs_enus
# 7978        34.0           259943_eng
# 13689       13.0  ib_iosa_a02_it_enus
# 7521        32.0       CONS0121000000
# 10274       37.0  lu_lalp_a04_it_enus
# 12796       12.0       _pc_ch_lach023
# 11076       10.0  cust_07_a02_bs_enus
# 11409       37.0       _pc_bi_ssbi001
# 13102       12.0       CUST8181000000
# 11375       37.0       _pc_bi_ssbi001
# 3482        30.0           259931_eng
# 8058         7.0  comm_11_a02_bs_enus
# 3482        30.0           259931_eng
# 19952       20.0  ib_itil_a09_it_enus
# 13689       13.0  ib_iosa_a02_it_enus
# 11144       37.0  lu_lalp_a04_it_enus
# 8944         8.0  proj_04_a04_bs_enus
# 24497       51.0       CUST0163000000
# 3886        30.0           259931_eng
# 11113       37.0  lu_lalp_a04_it_enus
# 1359        28.0  team_02_a04_bs_enus
# 7919         7.0  proj_04_a03_bs_enus
# 24792       52.0       CUST8182000000
# 18063       44.0  comm_26_a02_bs_enus
# 15742       41.0  team_02_a01_bs_enus
# 13641       39.0       COMM0233000000
# 16282       15.0        ADM0103000000
# 7920         7.0  proj_04_a03_bs_enus
# 25378       52.0       CUST8182000000
# 7978         7.0  proj_04_a03_bs_enus
# 3858         3.0            mntpmp5ed
# 16282       15.0        ADM0103000000
# 18371       17.0  ib_itlu_a01_it_enus
# 10810       10.0  cust_07_a02_bs_enus
# 3858         3.0            mntpmp5ed
# 3857         3.0            mntpmp5ed
# 1946        28.0  team_02_a04_bs_enus
# 12318       12.0       _pc_ch_lach023
# 15353       15.0  ib_iosa_a04_it_enus
# 15942       41.0  team_02_a01_bs_enus
# 853          0.0  comm_02_a01_bs_enus
# 24038       25.0           218741_eng
# 15715       15.0  ib_iosa_a04_it_enus
# 19391       18.0  ib_itlu_a06_it_enus
# 10100       34.0       CUST8103000000
# 13641       39.0       COMM0233000000
# 15742       41.0  team_02_a01_bs_enus
# 11113       37.0  lu_lalp_a04_it_enus
# 9207        34.0       CUST8103000000
# 24497       51.0       CUST0163000000
# 9784        36.0           259945_eng
# 6495        33.0           259942_eng
# 9784        36.0           259945_eng
# 15862       15.0        ADM0103000000
# 590          0.0  comm_02_a01_bs_enus
# 20557       47.0  cl_clbp_a01_it_enus
# 10100       34.0       CUST8103000000
# 18371       17.0  ib_itlu_a01_it_enus
# 12318       12.0       _pc_ch_lach023
# 11375       37.0       _pc_bi_ssbi001
# 1927        26.0                35331
# 8944         8.0  proj_04_a04_bs_enus
# 436         27.0         PD0133000000
# 15353       15.0  ib_iosa_a04_it_enus
# 9076         8.0       COMM8003000000
# 11409       37.0       _pc_bi_ssbi001
# 20557       47.0  cl_clbp_a01_it_enus
# 12682       12.0       CUST8181000000
# 1359        28.0  team_02_a04_bs_enus
# 24038       25.0           218741_eng
# 13102       12.0       CUST8181000000
# 10820       36.0  comm_02_a01_bs_enus
# 18386       17.0  ib_itlu_a01_it_enus
# 1946        28.0  team_02_a04_bs_enus
# 19391       18.0  ib_itlu_a06_it_enus
# 18063       44.0  comm_26_a02_bs_enus
# 17238       16.0  ib_iosa_a07_it_enus
# 7521        32.0       CONS0121000000
# 9152        33.0       CUST0163000000
# 24454       51.0       CUST0163000000
# 24792       52.0       CUST8182000000
# 5819         5.0    pd_24_a01_bs_enus
# 17238       16.0  ib_iosa_a07_it_enus
# 1927        26.0                35331
# 12554       12.0       _pc_ch_lach023
# 12796       12.0       _pc_ch_lach023
# 18748       19.0  cust_07_a03_bs_enus
# 3857         3.0            mntpmp5ed
# 6495        33.0           259942_eng
# 5819         5.0    pd_24_a01_bs_enus
# 12554       12.0       _pc_ch_lach023
# 15862       15.0        ADM0103000000
# 18748       19.0  cust_07_a03_bs_enus
# 11083       36.0  comm_02_a01_bs_enus
# 18386       17.0  ib_itlu_a01_it_enus
# 590          0.0  comm_02_a01_bs_enus
# 9152        33.0       CUST0163000000
# 11144       37.0  lu_lalp_a04_it_enus
# 9109        33.0       CUST0163000000
# 11147       37.0  lu_lalp_a04_it_enus
# 10810       10.0  cust_07_a02_bs_enus
# 10274       37.0  lu_lalp_a04_it_enus
# 6894         6.0  proj_04_a02_bs_enus
# 728         25.0                35320
# 19240       19.0  cust_07_a03_bs_enus
# 17939       18.0  cust_02_a02_bs_enus
# 7552        34.0           259943_eng
# 3590        30.0           259931_eng
# 1507        28.0  team_02_a04_bs_enus
# 17630       44.0  proj_06_a03_bs_enus
# 21283       47.0  cl_clbp_a01_it_enus
# 21614       21.0    pd_12_a01_bs_enus
# 2260        29.0           259928_eng
# 6450         6.0  proj_04_a02_bs_enus
# 13226       39.0  lu_lalp_a06_it_enus
# 23348       22.0       TEAM8223000000
# 13226       39.0  lu_lalp_a06_it_enus
# 21614       21.0    pd_12_a01_bs_enus
# 14712       14.0  ib_iosa_a03_it_enus
# 19375       18.0  ib_itlu_a06_it_enus
# 6698         6.0  proj_04_a02_bs_enus
# 19389       18.0  ib_itlu_a06_it_enus
# 7587         7.0  comm_11_a02_bs_enus
# 3640        30.0           259931_eng
# 8728         8.0       COMM8003000000
# 7634         7.0  comm_11_a02_bs_enus
# 16284       15.0        ADM0103000000
# 13643       39.0       COMM0233000000
# 19239       19.0  cust_07_a03_bs_enus
# 7555        34.0           259943_eng
# 19410       18.0  ib_itlu_a06_it_enus
# 18237       18.0  cust_02_a02_bs_enus
# 3443         3.0  proj_07_a01_bs_enus
# 13272       12.0       CUST8181000000
# 17447       44.0  proj_06_a03_bs_enus
# 10470       37.0  lu_lalp_a04_it_enus
# 12987       12.0       _pc_ch_lach023
# 17630       44.0  proj_06_a03_bs_enus
# 1932         1.0       CUST8126000000
# 24029       25.0           218741_eng
# 1975         1.0       CUST8126000000
# 16412       16.0  ib_iosa_a07_it_enus
# 7438        32.0       CONS0121000000
# 21283       47.0  cl_clbp_a01_it_enus
# 14712       14.0  ib_iosa_a03_it_enus
# 22216       21.0    pd_12_a01_bs_enus
# 5880         5.0  proj_04_a01_bs_enus
# 10742       10.0  cust_07_a02_bs_enus
# 7555        34.0           259943_eng
# 7438        32.0       CONS0121000000
# 13881       39.0       COMM0233000000
# 13895       39.0       COMM0233000000
# 4586        31.0           259935_eng
# 7634         7.0  comm_11_a02_bs_enus
# 2446         2.0    pd_05_a02_bs_enus
# 7587         7.0  comm_11_a02_bs_enus
# 13895       39.0       COMM0233000000
# 9153        33.0       CUST0163000000
# 455          0.0  comm_02_a01_bs_enus
# 13232       12.0       CUST8181000000
# 7866         7.0  comm_11_a02_bs_enus
# 12771       12.0       _pc_ch_lach023
# 7684        32.0       CONS0121000000
# 7552        34.0           259943_eng
# 18237       18.0  cust_02_a02_bs_enus
# 25541       52.0       CUST8182000000
# 3974        30.0           259931_eng
# 25540       52.0       CUST8182000000
# 13643       39.0       COMM0233000000
# 5880         5.0  proj_04_a01_bs_enus
# 24163       25.0           218741_eng
# 12987       12.0       _pc_ch_lach023
# 10742       10.0  cust_07_a02_bs_enus
# 3461        30.0           259931_eng
# 3457        30.0           259931_eng
# 13881       39.0       COMM0233000000
# 8728         8.0       COMM8003000000
# 11415       37.0       _pc_bi_ssbi001
# 13264       12.0       CUST8181000000
# 15506       15.0        ADM0103000000
# 8251         8.0  proj_04_a04_bs_enus
# 2446         2.0    pd_05_a02_bs_enus
# 15178       14.0  ib_iosa_a03_it_enus
# 23348       22.0       TEAM8223000000
# 22280       23.0  pm_proj_a04_tp_enus
# 6894         6.0  proj_04_a02_bs_enus
# 25064       53.0       en_us_69774_ek
# 9413        36.0           259945_eng
# 11415       37.0       _pc_bi_ssbi001
# 7684        32.0       CONS0121000000
# 3590        30.0           259931_eng
# 14470       14.0            76165_eng
# 25224       53.0       en_us_69774_ek
# 12771       12.0       _pc_ch_lach023
# 3850         3.0            mntpmp5ed
# 11046       10.0  proj_04_a06_bs_enus
# 17447       44.0  proj_06_a03_bs_enus
# 9153        33.0       CUST0163000000
# 3461        30.0           259931_eng
# 17939       18.0  cust_02_a02_bs_enus
# 3457        30.0           259931_eng
# 25224       53.0       en_us_69774_ek
# 22280       23.0  pm_proj_a04_tp_enus
# 25064       53.0       en_us_69774_ek
# 19393  ITIL V3 Foundation Syllabus v4.2: Service Tran...         979.0
# 19992  Getting Results without Direct Authority: Pers...         555.0
# 17355   ITIL? V3 OSA: Introduction to Problem Management         987.0
# 19992  Getting Results without Direct Authority: Pers...         555.0
# 17355   ITIL? V3 OSA: Introduction to Problem Management         987.0
# 15316  ITIL? V3 OSA: Introduction to Incident Managem...         994.0
# 15316  ITIL? V3 OSA: Introduction to Incident Managem...         994.0
# 5871   Overview of Project Managing a PRINCE2-aligned...         756.0
# 16198             Using Effective Business Communication         853.0
# 16198             Using Effective Business Communication         853.0
# 18365  ITIL V3 Foundation Syllabus v4.2: ITIL and the...         974.0
# 17362   ITIL? V3 OSA: Introduction to Problem Management         994.0
# 20418  ITIL V3 Foundation Syllabus v4.2: Service Oper...         981.0
# 17193   ITIL? V3 OSA: Introduction to Problem Management         825.0
# 14293    ITIL? V3 OSA: Introduction to Event Management          994.0
# 18365  ITIL V3 Foundation Syllabus v4.2: ITIL and the...         974.0
# 17362   ITIL? V3 OSA: Introduction to Problem Management         994.0
# 14293    ITIL? V3 OSA: Introduction to Event Management          994.0
# 20418  ITIL V3 Foundation Syllabus v4.2: Service Oper...         981.0
# 17193   ITIL? V3 OSA: Introduction to Problem Management         825.0
# 17356   ITIL? V3 OSA: Introduction to Problem Management         988.0
# 18969  Getting Results without Direct Authority: Buil...         555.0
# 17356   ITIL? V3 OSA: Introduction to Problem Management         988.0
# 18969  Getting Results without Direct Authority: Buil...         555.0
# 14291    ITIL? V3 OSA: Introduction to Event Management          992.0
# 14291    ITIL? V3 OSA: Introduction to Event Management          992.0
# 10810          Interpersonal Communications: The Process         580.0
# 580            Interpersonal Communications: The Process         580.0
# 10810          Interpersonal Communications: The Process         580.0
# 15314  ITIL? V3 OSA: Introduction to Incident Managem...         992.0
# 23445                  Writing Effective E-mail Messages         939.0
# 580            Interpersonal Communications: The Process         580.0
# ...
# 17365         62.0
# 17363         62.0
# 17358         62.0
# 19395         62.0
# 14294         62.0
# 13588         62.0
# 3845          62.0
# 12935         62.0
# 12674         62.0
# 21529         62.0
# 3901          62.0
# 15927         62.0
# 3860          62.0
# 3871          62.0
# 15892         62.0
# 6903          62.0
# 3867          62.0
# 22261         62.0
# 19395         62.0
# 6895          62.0
# 3845          62.0
# 12674         62.0
# 17901         61.0
# 959           61.0
# 12223         61.0
# 3843          61.0
# 3843          61.0
# 1551          61.0
# 3866          61.0
# 11771         61.0
# 17973         61.0
# 21437         61.0
# 21437         61.0
# 24596         61.0
# 3864          61.0
# 10778         61.0
# 6896          61.0
# 3866          61.0
# 10778         61.0
# 1973          61.0
# 1973          61.0
# 17973         61.0
# 12223         61.0
# 11771         61.0
# 959           61.0
# 3864          61.0
# 24596         61.0
# 6896          61.0
# 17901         61.0
# 1551          61.0
# 14152         60.0
# 15317         60.0
# 21435         60.0
# 15311         60.0
# 15311         60.0
# 6945          60.0
# 7816          60.0
# 1024          60.0
# 14152         60.0
# 18593         60.0
# 15084         60.0
# 7816          60.0
# 15317         60.0
# 24562         60.0
# 16269         60.0
# 22224         60.0
